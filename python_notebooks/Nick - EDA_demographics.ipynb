# %% [markdown]
# # Population Fluidity

# %% [markdown]
# To Do:
# Create connection to data source and perform basic EDA

# %% [markdown]
# [Variable information for ACS data](https://www.census.gov/data/developers/data-sets/acs-1year/notes-on-acs-api-variable-types.html)
#
# [Guidance for Developers](https://www.census.gov/data/developers/guidance.html)
#
# [Example of building API Call From US Census](https://www.census.gov/library/video/2020/using-api-all-results-for-acs-table.html)
#
# [Query String Wiki](https://en.wikipedia.org/wiki/Query_string)
#
# [Examples for 2020 ACS flow data](https://api.census.gov/data/2020/acs/flows/examples.html)

# %% [markdown]
# # Libraries

# %%
# Libraries

## Base -------
import pandas as pd
import numpy as np
import requests
import glob
import datetime
import h5py
import time
import timeit

## Handling requests -------
from requests.exceptions import HTTPError

## Timeouts if the server takes too long -------
from requests.exceptions import Timeout
import json

## Graphing --------
import seaborn as sns

## Google drive connections ---------
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Functions

# %%
def get_data(url, timeout = 1): 
  """ 
    Used to get the data from a url
    Add in limits
  """
  try:
      response = requests.get(url)

      # If the response was successful, no Exception will be raised
      response.raise_for_status()
      
  except HTTPError as http_err:
      print(f'HTTP error occurred: {http_err}')  # Python 3.6
  except Timeout:
    print('The request timed out')
  except Exception as err:
      print(f'Other error occurred: {err}')  # Python 3.6
  else:
      print('Success!')
      return response

# %%
import pickle
import os

def pickler(ob, pklFileName):
  """ 
    Create pickle object to load later or in different environments for use later

    ob: object, python object intended to pickle
    pklFileName: string, name of the pickle file e.g. "User/content/drive/209/ThisDataFrame.pkl"
  """
  
  with open(pklFileName, "wb+") as f:
    pickle.dump(ob, f)

def load_pickles(pklFilePath):
  """
    path: string, path to object
    pklFileName: string, pickle file name with extension .pkl
  """

  return pd.read_pickle(pklFilePath)

# %%
def json_to_df(response):
  """ 

  """

  df = pd.DataFrame(response.json())
  df = df.rename(columns=df.iloc[0]).drop(df.index[0]) # replace column names with the first row

  return df

# %% [markdown]
# # Import Data

# %%
# get state and country codes
stateCodes = pd.read_csv("https://www2.census.gov/geo/docs/reference/state.txt", sep="|")
stateCodes
# Out:
#     STATE STUSAB                   STATE_NAME  STATENS
# 0       1     AL                      Alabama  1779775
# 1       2     AK                       Alaska  1785533
# 2       4     AZ                      Arizona  1779777
# 3       5     AR                     Arkansas    68085
# 4       6     CA                   California  1779778
# 5       8     CO                     Colorado  1779779
# 6       9     CT                  Connecticut  1779780
# 7      10     DE                     Delaware  1779781
# 8      11     DC         District of Columbia  1702382
# 9      12     FL                      Florida   294478
# 10     13     GA                      Georgia  1705317
# 11     15     HI                       Hawaii  1779782
# 12     16     ID                        Idaho  1779783
# 13     17     IL                     Illinois  1779784
# 14     18     IN                      Indiana   448508
# 15     19     IA                         Iowa  1779785
# 16     20     KS                       Kansas   481813
# 17     21     KY                     Kentucky  1779786
# 18     22     LA                    Louisiana  1629543
# 19     23     ME                        Maine  1779787
# 20     24     MD                     Maryland  1714934
# 21     25     MA                Massachusetts   606926
# 22     26     MI                     Michigan  1779789
# 23     27     MN                    Minnesota   662849
# 24     28     MS                  Mississippi  1779790
# 25     29     MO                     Missouri  1779791
# 26     30     MT                      Montana   767982
# 27     31     NE                     Nebraska  1779792
# 28     32     NV                       Nevada  1779793
# 29     33     NH                New Hampshire  1779794
# 30     34     NJ                   New Jersey  1779795
# 31     35     NM                   New Mexico   897535
# 32     36     NY                     New York  1779796
# 33     37     NC               North Carolina  1027616
# 34     38     ND                 North Dakota  1779797
# 35     39     OH                         Ohio  1085497
# 36     40     OK                     Oklahoma  1102857
# 37     41     OR                       Oregon  1155107
# 38     42     PA                 Pennsylvania  1779798
# 39     44     RI                 Rhode Island  1219835
# 40     45     SC               South Carolina  1779799
# 41     46     SD                 South Dakota  1785534
# 42     47     TN                    Tennessee  1325873
# 43     48     TX                        Texas  1779801
# 44     49     UT                         Utah  1455989
# 45     50     VT                      Vermont  1779802
# 46     51     VA                     Virginia  1779803
# 47     53     WA                   Washington  1779804
# 48     54     WV                West Virginia  1779805
# 49     55     WI                    Wisconsin  1779806
# 50     56     WY                      Wyoming  1779807
# 51     60     AS               American Samoa  1802701
# 52     66     GU                         Guam  1802705
# 53     69     MP     Northern Mariana Islands  1779809
# 54     72     PR                  Puerto Rico  1779808
# 55     74     UM  U.S. Minor Outlying Islands  1878752
# 56     78     VI          U.S. Virgin Islands  1802710

# %%
# getting all the info! 
# !wget "https://geonames.usgs.gov/docs/stategaz/NationalFile.zip" &> dev/null

# %%
# county codes: 
# https://geonames.usgs.gov/docs/federalcodes/AllStatesFedCodes.zip
# comprehensive file for counties, states, coordinates
# https://geonames.usgs.gov/docs/stategaz/NationalFile.zip

# %% [markdown]
# # Demographic Data

# %%
"https://api.census.gov/data/2010/acs/flows?get=MOVEDIN,GEOID1,GEOID2,MOVEDOUT,FULL1_NAME,FULL2_NAME,MOVEDNET&for=county:*&in=state:36" # state and county are required for 2010

# %% [markdown]
# Buidling out the parameters to pass to requests

# %%
def json_to_df(response):
  """ 

  """

  df = pd.DataFrame(response.json())
  df = df.rename(columns=df.iloc[0]).drop(df.index[0]) # replace column names with the first row

  return df

# %%
from time import sleep
from tqdm.notebook import tqdm # progress bar library

# %%
data = {}

# %%
variables = ["MOVEDIN",
    "GEOID1",
    "GEOID2",
    "MOVEDOUT",
    "FULL1_NAME",
    "FULL2_NAME",
    "MOVEDNET"
  ]

variables = ",".join(variables)
variables
# Out:
# 'MOVEDIN,GEOID1,GEOID2,MOVEDOUT,FULL1_NAME,FULL2_NAME,MOVEDNET'

# %%
for y in tqdm(range(2010, 2022)):
  print("Adding year: ", y)

  if y in data.keys(): # skip over if the data is already there. 
    continue
  
  # create year url
  url = f"https://api.census.gov/data/{y}/acs/flows?" # can add back MOVEDIN,MOVEDOUT

  # change payload based on year
  if y < 2016: # loop over states since I can only  call one at a time apparently before 2016
    
    y_df = pd.DataFrame() # empty dataframe to store year data

    for s in tqdm(stateCodes["STATE"]):

      if s < 10: 
        s = "0"+str(s) # need two digit code
      payload = {"get": variables,"for": "county:*", "in":"state:"+str(s)}
      r = requests.get(url, params = payload)
      if r.status_code == 200:
        y_df = pd.concat([y_df, json_to_df(r)])

    # add year
    y_df["YEAR"] = y

    print(f"{y} dimensions {y_df.shape}")
    
    # write out data to larger dictionary
    data[y] = y_df
    
    del y_df

  else: 
    payload = {"get": variables,"for": "county:*"}
    r = requests.get(url, params = payload)
    
    if r.status_code == 200: # then add to the dataframe else skip
      y_df = json_to_df(r)
      y_df['YEAR'] = y
      print(f"{y} dimensions {y_df.shape}")
      data[y] = y_df
      del y_df
    
    data[y] = ""
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# Adding year:  2010
# Adding year:  2011
# Adding year:  2012
#   0%|          | 0/57 [00:00<?, ?it/s]

# %%
sum(data[2010].duplicated())
# Out:
# 0

# %%
data = {}

for y,url in url_years.items():
  start_time = timeit.default_timer()

  key = "migration_" + str(y)   
  print("Adding year: ", y)

  try:
    r = get_data(url)

    # in case it fails
    data[key] = pd.DataFrame(r.json())

  except: 
    pass

  elapsed = timeit.default_timer() - start_time
  print("Elapsed time: ", round(elapsed/60, 2))

# %%
# for s in stateCodes["STATE"]:

# %%
url1 = "https://api.census.gov/data/2011/acs/flows?get=MOVEDIN,GEOID1,GEOID2,MOVEDOUT,FULL1_NAME,FULL2_NAME,MOVEDNET&for=county:*&in=state:50"
url2 = "https://api.census.gov/data/2011/acs/flows?get=MOVEDIN,GEOID1,GEOID2,MOVEDOUT,FULL1_NAME,FULL2_NAME,MOVEDNET&for=county:*&in=state:49"

r1 = requests.get(url1)
r2 = requests.get(url2)

# %%
d1 = json_to_df(r1)

# %%
d2 = json_to_df(r2)

# %%
df = pd.concat([d1, d2])

# %%
df['YEAR'] = 2010

# %%
df
# Out:
#      MOVEDIN GEOID1      GEOID2 MOVEDOUT               FULL1_NAME  \
# 1         58  50001        None     None  Addison County, Vermont
# 2         69  50001        None     None  Addison County, Vermont
# 3        169  50001        None     None  Addison County, Vermont
# 4         50  50001        None     None  Addison County, Vermont
# 5         17  50001        None     None  Addison County, Vermont
# ...      ...    ...         ...      ...                      ...
# 4423       0  49049  5508100475        9        Utah County, Utah
# 4424       8  49049  5508702375        0        Utah County, Utah
# 4425       6  49049  5508782400        0        Utah County, Utah
# 4426       0  49049  5511773050        3        Utah County, Utah
# 4427      11  49049  5513383175        0        Utah County, Utah
#
#                                              FULL2_NAME MOVEDNET state county  \
# 1                                                  Asia     None    50    001
# 2                                       Central America     None    50    001
# 3                                                Europe     None    50    001
# 4                                      Northern America     None    50    001
# 5                                    Oceania and At Sea     None    50    001
# ...                                                 ...      ...   ...    ...
# 4423              Adrian town, Monroe County, Wisconsin       -9    49    049
# 4424         Appleton city, Outagamie County, Wisconsin        8    49    049
# 4425      Vandenbroek town, Outagamie County, Wisconsin        6    49    049
# 4426  Sheboygan Falls town, Sheboygan County, Wisconsin       -3    49    049
# 4427          Wales village, Waukesha County, Wisconsin       11    49    049
#
#       YEAR
# 1     2010
# 2     2010
# 3     2010
# 4     2010
# 5     2010
# ...    ...
# 4423  2010
# 4424  2010
# 4425  2010
# 4426  2010
# 4427  2010
#
# [6240 rows x 10 columns]

# %% [markdown]
# # Demographics

# %%
import requests
import pandas as pd

# %%
# YEAR VARIABLES
r = requests.get("https://api.census.gov/data/2010/acs/flows/variables")
r.status_code
# Out:
# 200

# %%
variables = pd.DataFrame(r.json())
variables = variables.rename(columns=variables.iloc[0]).drop(variables.index[0])

# %%
variables
# Out:
#                name                                              label  \
# 1               for                       Census API FIPS 'for' clause
# 2                in                        Census API FIPS 'in' clause
# 3     FROMDIFFCTY_M  Movers from different county, same state margi...
# 4       TODIFFCTY_M  Movers to different county, same state margin ...
# 5            STATE1             FIPS State code of reference geography
# 6            STATE2   State code/world region code of second geography
# 7        MOVEDNET_M                Total net migration margin of error
# 8       STATE1_NAME             FIPS State name of reference geography
# 9          POP1YR_M         Population 1 year and over margin of error
# 10          SUMLEV2       Geographic summary level of second geography
# 11          MOVEDIN  Total inbound migration to reference geography...
# 12     COUNTY1_NAME            FIPS county name of reference geography
# 13      POP1YRAGO_M  Population living in county 1 year ago margin ...
# 14       FROMABROAD                                 Movers from abroad
# 15             MCD2                  FIPS MCD code of second geography
# 16        SAMEMCD_M             Movers within same MCD margin of error
# 17          SAMEMCD                             Movers within same MCD
# 18             MCD1               FIPS MCD code of reference geography
# 19        TODIFFCTY             Movers to different county, same state
# 20     COUNTY2_NAME  FIPS county name of second geography (blank fo...
# 21       MOVEDOUT_M           Total outbound migration margin of error
# 22           POP1YR                         Population 1 year and over
# 23        MCD2_NAME  MCD name of second geography (blank for world ...
# 24           GEOID1         Combined codes for the reference geography
# 25           GEOID2            Combined codes for the second geography
# 26      FROMDIFFMCD              Movers from different MCD, same state
# 27          COUNTY1            FIPS county code of reference geography
# 28   TOPUERTORICO_M              Movers to Puerto Rico margin of error
# 29              SEX                                   Characteristic 1
# 30         MOVEDOUT                           Total outbound migration
# 31        TODIFFMCD                Movers to different MCD, same state
# 32      TODIFFSTATE                          Movers to different state
# 33    FROMDIFFSTATE                        Movers from different state
# 34          COUNTY2               FIPS county code of second geography
# 35        MOVEDIN_M            Total inbound migration margin of error
# 36      HISP_ORIGIN                                   Characteristic 4
# 37     SAMECOUNTY_M          Movers within same county margin of error
# 38       FULL1_NAME                   Full name of reference geography
# 39     TOPUERTORICO                              Movers to Puerto Rico
# 40        NONMOVERS              Same residence 1 year ago (nonmovers)
# 41              AGE                                   Characteristic 2
# 42    FROMDIFFMCD_M  Movers from different MCD, same state margin o...
# 43      NONMOVERS_M  Same residence 1 year ago (nonmovers) margin o...
# 44      FROMDIFFCTY           Movers from different county, same state
# 45      TODIFFMCD_M  Movers to different MCD, same state margin of ...
# 46  FROMDIFFSTATE_M        Movers from different state margin of error
# 47      STATE2_NAME   State code/world region name of second geography
# 48        POP1YRAGO             Population living in county 1 year ago
# 49          SUMLEV1    Geographic summary level of reference geography
# 50        MCD1_NAME                    MCD name of reference geography
# 51       FULL2_NAME                      Full name of second geography
# 52             RACE                                   Characteristic 3
# 53     FROMABROAD_M                 Movers from abroad margin of error
# 54         MOVEDNET                                Total net migration
# 55       SAMECOUNTY                          Movers within same county
# 56    TODIFFSTATE_M          Movers to different state margin of error
#
#                                concept
# 1   Census API Geography Specification
# 2   Census API Geography Specification
# 3                    Estimate Variable
# 4                    Estimate Variable
# 5               Selectable Geographies
# 6               Selectable Geographies
# 7                    Estimate Variable
# 8               Selectable Geographies
# 9                    Estimate Variable
# 10              Selectable Geographies
# 11                   Estimate Variable
# 12              Selectable Geographies
# 13                   Estimate Variable
# 14                   Estimate Variable
# 15              Selectable Geographies
# 16                   Estimate Variable
# 17                   Estimate Variable
# 18              Selectable Geographies
# 19                   Estimate Variable
# 20              Selectable Geographies
# 21                   Estimate Variable
# 22                   Estimate Variable
# 23              Selectable Geographies
# 24              Selectable Geographies
# 25              Selectable Geographies
# 26                   Estimate Variable
# 27              Selectable Geographies
# 28                   Estimate Variable
# 29                   Estimate Variable
# 30                   Estimate Variable
# 31                   Estimate Variable
# 32                   Estimate Variable
# 33                   Estimate Variable
# 34              Selectable Geographies
# 35                   Estimate Variable
# 36                   Estimate Variable
# 37                   Estimate Variable
# 38              Selectable Geographies
# 39                   Estimate Variable
# 40                   Estimate Variable
# 41                   Estimate Variable
# 42                   Estimate Variable
# 43                   Estimate Variable
# 44                   Estimate Variable
# 45                   Estimate Variable
# 46                   Estimate Variable
# 47              Selectable Geographies
# 48                   Estimate Variable
# 49              Selectable Geographies
# 50              Selectable Geographies
# 51              Selectable Geographies
# 52                   Estimate Variable
# 53                   Estimate Variable
# 54                   Estimate Variable
# 55                   Estimate Variable
# 56                   Estimate Variable

# %%
variables = ["MOVEDIN",
    "GEOID1",
    "GEOID2",
    "MOVEDOUT",
    "FULL1_NAME",
    "FULL2_NAME",
    "MOVEDNET", 
    "TODIFFSTATE",
    "FROMDIFFSTATE",
    "SEX",
    "AGE",
    "RACE"
  ]

variables = ",".join(variables)
variables
# Out:
# 'MOVEDIN,GEOID1,GEOID2,MOVEDOUT,FULL1_NAME,FULL2_NAME,MOVEDNET,TODIFFSTATE,FROMDIFFSTATE,SEX,AGE,RACE'

# %%
data = {}

# %%
for y in tqdm(range(2010, 2012)):
  print("Adding year: ", y)

  if y in data.keys(): # skip over if the data is already there. 
    continue
  
  # create year url
  url = f"https://api.census.gov/data/{y}/acs/flows?" # can add back MOVEDIN,MOVEDOUT

  # change payload based on year
  if y < 2016: # loop over states since I can only  call one at a time apparently before 2016
    
    y_df = pd.DataFrame() # empty dataframe to store year data

    for s in tqdm(stateCodes["STATE"]):

      if s < 10: 
        s = "0"+str(s) # need two digit code
      payload = {"get": variables,"for": "county:*", "in":"state:"+str(s)}
      r = requests.get(url, params = payload)
      if r.status_code == 200:
        y_df = pd.concat([y_df, json_to_df(r)])

    # add year
    y_df["YEAR"] = y

    print(f"{y} dimensions {y_df.shape}")
    
    # write out data to larger dictionary
    data[y] = y_df
    
    del y_df

  else: 
    payload = {"get": variables,"for": "county:*"}
    r = requests.get(url, params = payload)
    
    if r.status_code == 200: # then add to the dataframe else skip
      y_df = json_to_df(r)
      y_df['YEAR'] = y
      print(f"{y} dimensions {y_df.shape}")
      data[y] = y_df
      del y_df
    
    data[y] = ""
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Adding year:  2010
#   0%|          | 0/57 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in _error_catcher(self)
#     361             try:
# --> 362                 yield
#     363
#
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     670                     break
# --> 671                 chunk = self._handle_chunk(amt)
#     672                 decoded = self._decode(chunk, decode_content=decode_content,
#
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in _handle_chunk(self, amt)
#     616         elif amt < self.chunk_left:
# --> 617             value = self._fp._safe_read(amt)
#     618             self.chunk_left = self.chunk_left - amt
#
# /usr/lib/python3.8/http/client.py in _safe_read(self, amt)
#     612         """
# --> 613         data = self.fp.read(amt)
#     614         if len(data) < amt:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/requests/models.py in generate()
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     491         if self.chunked and self.supports_chunked_reads():
# --> 492             for line in self.read_chunked(amt, decode_content=decode_content):
#     493                 yield line
#
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     695             if self._original_response:
# --> 696                 self._original_response.close()
#     697
#
# /usr/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# /usr/local/lib/python3.8/dist-packages/urllib3/response.py in _error_catcher(self)
#     379                 # This includes IncompleteRead.
# --> 380                 raise ProtocolError('Connection broken: %r' % e, e)
#     381
#
# ProtocolError: ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# <ipython-input-28-21873c897137> in <module>
#      18         s = "0"+str(s) # need two digit code
#      19       payload = {"get": variables,"for": "county:*", "in":"state:"+str(s)}
# ---> 20       r = requests.get(url, params = payload)
#      21       if r.status_code == 200:
#      22         y_df = pd.concat([y_df, json_to_df(r)])
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.8/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /usr/local/lib/python3.8/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in content(self)
#     829                 self._content = None
#     830             else:
# --> 831                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     832
#     833         self._content_consumed = True
#
# /usr/local/lib/python3.8/dist-packages/requests/models.py in generate()
#     754                         yield chunk
#     755                 except ProtocolError as e:
# --> 756                     raise ChunkedEncodingError(e)
#     757                 except DecodeError as e:
#     758                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))
