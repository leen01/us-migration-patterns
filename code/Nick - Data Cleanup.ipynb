# %% [markdown]
# Adding county columns and state moved to column

# %%
import pandas as pd
import numpy as np
import pickle

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load data
pklFile = "/content/drive/MyDrive/W209_final_project/Data/PickleFiles/df_final20230221.pkl"
df = pd.read_pickle(pklFile)

# %%
df = df.drop(axis = 1, labels = ["state", "county", "STATE", "STATENS", "STUSAB"])

# %%
df[df["STATE_NAME"] == "Arizona"]
# Out:
#         MOVEDIN GEOID1      GEOID2 MOVEDOUT              FULL1_NAME  \
# 11504        64  04001       02020        0  Apache County, Arizona
# 11505        36  04001       02090        4  Apache County, Arizona
# 11506         0  04001       02122       12  Apache County, Arizona
# 11507         0  04001       04003      166  Apache County, Arizona
# 11508       177  04001       04005       94  Apache County, Arizona
# ...         ...    ...         ...      ...                     ...
# 4984829       0  04027  5503968175        4    Yuma County, Arizona
# 4984830       8  04027  5505578200        0    Yuma County, Arizona
# 4984831      41  04027  5505939225        0    Yuma County, Arizona
# 4984832      76  04027  5506127250        0    Yuma County, Arizona
# 4984833      49  04027  5507953000        0    Yuma County, Arizona
#
#                                           FULL2_NAME  MOVEDNET  YEAR  \
# 11504                 Anchorage Municipality, Alaska        64  2010
# 11505           Fairbanks North Star Borough, Alaska        32  2010
# 11506                Kenai Peninsula Borough, Alaska       -12  2010
# 11507                        Cochise County, Arizona      -166  2010
# 11508                       Coconino County, Arizona        83  2010
# ...                                              ...       ...   ...
# 4984829    Ripon City, Fond du Lac County, Wisconsin        -4  2020
# 4984830   Sullivan Town, Jefferson County, Wisconsin         8  2020
# 4984831      Kenosha City, Kenosha County, Wisconsin        41  2020
# 4984832    Franklin Town, Kewaunee County, Wisconsin        76  2020
# 4984833  Milwaukee City, Milwaukee County, Wisconsin        49  2020
#
#         STATE_NAME
# 11504      Arizona
# 11505      Arizona
# 11506      Arizona
# 11507      Arizona
# 11508      Arizona
# ...            ...
# 4984829    Arizona
# 4984830    Arizona
# 4984831    Arizona
# 4984832    Arizona
# 4984833    Arizona
#
# [77785 rows x 9 columns]

# %%
df.head()
# Out:
#   MOVEDIN GEOID1 GEOID2 MOVEDOUT               FULL1_NAME  \
# 0      38  01001  01003       11  Autauga County, Alabama
# 1       0  01001  01005       15  Autauga County, Alabama
# 2      44  01001  01007        0  Autauga County, Alabama
# 3      98  01001  01009       59  Autauga County, Alabama
# 4      12  01001  01013        0  Autauga County, Alabama
#
#                 FULL2_NAME  MOVEDNET  YEAR STATE_NAME
# 0  Baldwin County, Alabama        27  2010    Alabama
# 1  Barbour County, Alabama       -15  2010    Alabama
# 2     Bibb County, Alabama        44  2010    Alabama
# 3   Blount County, Alabama        39  2010    Alabama
# 4   Butler County, Alabama        12  2010    Alabama

# %% [markdown]
# IDENTIFIERS REFERENCE: https://www.census.gov/programs-surveys/geography/guidance/geo-identifiers.html

# %%
# get everything to 5 digit code
df["GEOID1"] = df["GEOID1"].str[:2] + df["GEOID1"].str[2:5]
df["GEOID2"] = df["GEOID2"].str[:2] + df["GEOID2"].str[2:5]

# %%
# Add human readable labels
dfCounty2010_2014 = pd.read_csv("https://www2.census.gov/geo/docs/reference/codes/national_county.txt", sep=",", dtype=object) # 2010 - 2014 encodings
dfCounty2010_2014["GEOID"] = dfCounty2010_2014["State ANSI"] + dfCounty2010_2014["County ANSI"]
dfCounty2010_2014 = dfCounty2010_2014.drop(["ANSI Cl"], axis = 1)

dfCounty2020 = pd.read_csv("https://www2.census.gov/geo/docs/reference/codes2020/national_county2020.txt", sep="|", dtype=object) # 2015 - 2020 encodings
dfCounty2020["GEOID"] = dfCounty2020['STATEFP'] + dfCounty2020["COUNTYFP"]
dfCounty2020 = dfCounty2020.drop(["CLASSFP", "FUNCSTAT", 'COUNTYNS'], axis = 1)

# %%
dfCounty = pd.merge(dfCounty2010_2014, dfCounty2020, how = "outer", on = "GEOID")
dfCounty.head()
# Out:
#   State State ANSI County ANSI     County Name  GEOID STATE STATEFP COUNTYFP  \
# 0    AL         01         001  Autauga County  01001    AL      01      001
# 1    AL         01         003  Baldwin County  01003    AL      01      003
# 2    AL         01         005  Barbour County  01005    AL      01      005
# 3    AL         01         007     Bibb County  01007    AL      01      007
# 4    AL         01         009   Blount County  01009    AL      01      009
#
#        COUNTYNAME
# 0  Autauga County
# 1  Baldwin County
# 2  Barbour County
# 3     Bibb County
# 4   Blount County

# %%
# restructure
dfCounty.isnull().sum()
# Out:
# State          4
# State ANSI     4
# County ANSI    4
# County Name    4
# GEOID          0
# STATE          4
# STATEFP        4
# COUNTYFP       4
# COUNTYNAME     4
# dtype: int64

# %%
# fill in empty
for i, k in zip(list(dfCounty2010_2014.columns), list(dfCounty2020.columns)): 
  dfCounty[k] = dfCounty[k].fillna(dfCounty[i])

del dfCounty2010_2014, dfCounty2020

# %%
# quality check
dfCounty.isnull().sum()
# Out:
# State          4
# State ANSI     4
# County ANSI    4
# County Name    4
# GEOID          0
# STATE          0
# STATEFP        0
# COUNTYFP       0
# COUNTYNAME     0
# dtype: int64

# %%
# remove extra columns
dfCounty.drop(axis = 1, inplace = True, labels = ['State', 'State ANSI', 'County ANSI', 'County Name', "STATEFP", "COUNTYFP"])

# %%
dfCounty.head()
# Out:
#    GEOID STATE      COUNTYNAME
# 0  01001    AL  Autauga County
# 1  01003    AL  Baldwin County
# 2  01005    AL  Barbour County
# 3  01007    AL     Bibb County
# 4  01009    AL   Blount County

# %%
df.head()
# Out:
#   MOVEDIN GEOID1 GEOID2 MOVEDOUT               FULL1_NAME  \
# 0      38  01001  01003       11  Autauga County, Alabama
# 1       0  01001  01005       15  Autauga County, Alabama
# 2      44  01001  01007        0  Autauga County, Alabama
# 3      98  01001  01009       59  Autauga County, Alabama
# 4      12  01001  01013        0  Autauga County, Alabama
#
#                 FULL2_NAME  MOVEDNET  YEAR STATE_NAME
# 0  Baldwin County, Alabama        27  2010    Alabama
# 1  Barbour County, Alabama       -15  2010    Alabama
# 2     Bibb County, Alabama        44  2010    Alabama
# 3   Blount County, Alabama        39  2010    Alabama
# 4   Butler County, Alabama        12  2010    Alabama

# %%
df.shape
# Out:
# (5437049, 9)

# %%
df = pd.merge(left= df, right = dfCounty, left_on = "GEOID1", right_on = "GEOID", suffixes = ("_OG1", "_FROM"), how = "outer")
df = pd.merge(left= df, right = dfCounty, left_on = "GEOID2", right_on = "GEOID", suffixes = ("_FROM", "_TO"), how = "outer")
df.isnull().sum()
# Out:
# MOVEDIN            28
# GEOID1             28
# GEOID2             28
# MOVEDOUT           28
# FULL1_NAME         28
# FULL2_NAME         28
# MOVEDNET           28
# YEAR               28
# STATE_NAME         28
# GEOID_FROM         14
# STATE_FROM         14
# COUNTYNAME_FROM    14
# GEOID_TO           14
# STATE_TO           14
# COUNTYNAME_TO      14
# dtype: int64

# %%
df.shape
# Out:
# (5437077, 15)

# %%
# cleanup columns
df.drop(inplace = True, axis = 1, labels = ["GEOID1", "GEOID2", "FULL1_NAME", "FULL2_NAME"])

# %%
df.head()
# Out:
#   MOVEDIN MOVEDOUT  MOVEDNET    YEAR STATE_NAME GEOID_FROM STATE_FROM  \
# 0      38       11      27.0  2010.0    Alabama      01001         AL
# 1      78        7      71.0  2011.0    Alabama      01001         AL
# 2     119       27      92.0  2012.0    Alabama      01001         AL
# 3     116       62      54.0  2013.0    Alabama      01001         AL
# 4      77       88     -11.0  2014.0    Alabama      01001         AL
#
#   COUNTYNAME_FROM GEOID_TO STATE_TO   COUNTYNAME_TO
# 0  Autauga County    01003       AL  Baldwin County
# 1  Autauga County    01003       AL  Baldwin County
# 2  Autauga County    01003       AL  Baldwin County
# 3  Autauga County    01003       AL  Baldwin County
# 4  Autauga County    01003       AL  Baldwin County

# %%
# add rustbelt label
rustbelt_states = ['Illinois', 'Indiana', 'Michigan', 'Missouri', 'New York', 'Ohio', 'Pennsylvania', 'West Virginia', 'Wisconsin']

states = pd.read_csv("/content/drive/MyDrive/W209_final_project/Data/state_abbreviations.csv")

# %%
df["STATE_FROM"] = pd.merge(df["STATE_FROM"], states, left_on = "STATE_FROM", right_on = "Abbreviation", how = "outer")["STATE"]
df["STATE_TO"] = pd.merge(df["STATE_TO"], states, left_on = "STATE_TO", right_on = "Abbreviation", how = "outer")["STATE"]

# %%
df.drop(inplace = True, axis = 1, labels = ['STATE_NAME'])
df.head()
# Out:
#   MOVEDIN MOVEDOUT  MOVEDNET    YEAR GEOID_FROM STATE_FROM COUNTYNAME_FROM  \
# 0      38       11      27.0  2010.0      01001    Alabama  Autauga County
# 1      78        7      71.0  2011.0      01001    Alabama  Autauga County
# 2     119       27      92.0  2012.0      01001    Alabama  Autauga County
# 3     116       62      54.0  2013.0      01001    Alabama  Autauga County
# 4      77       88     -11.0  2014.0      01001    Alabama  Autauga County
#
#   GEOID_TO STATE_TO   COUNTYNAME_TO
# 0    01003  Alabama  Baldwin County
# 1    01003  Alabama  Baldwin County
# 2    01003  Alabama  Baldwin County
# 3    01003  Alabama  Baldwin County
# 4    01003  Alabama  Baldwin County

# %%
df.isnull().sum()
# Out:
# MOVEDIN            28
# MOVEDOUT           28
# MOVEDNET           28
# YEAR               28
# GEOID_FROM         14
# STATE_FROM         15
# COUNTYNAME_FROM    14
# GEOID_TO           14
# STATE_TO           15
# COUNTYNAME_TO      14
# dtype: int64

# %%
def rustbelt_state_label(s): 
  if s in rustbelt_states: 
    return "Yes"
  else:
    return "No"

# %%
df["STATE_FROM_RustBelt_Label"] = df['STATE_FROM'].apply(rustbelt_state_label)
df["STATE_TO_RustBelt_Label"] = df['STATE_TO'].apply(rustbelt_state_label)

# %%
# Remove Null columns

# %%
import datetime
today = datetime.date.today()
today = datetime.date.strftime(today, "%Y%m%d")

# %%
# Write out csv
df.to_csv("/content/drive/MyDrive/W209_final_project/Data/df_county_sep_"+today+".csv")

# %%
df[df["STATE_TO"] == "Washington"]
# Out:
#         MOVEDIN MOVEDOUT  MOVEDNET    YEAR GEOID_FROM    STATE_FROM  \
# 3852732      11        0      11.0  2012.0      12109        Oregon
# 3852733       0       16     -16.0  2012.0      12109        Oregon
# 3852734      69       50      19.0  2013.0      12109        Oregon
# 3852735       0       30     -30.0  2013.0      12109        Oregon
# 3852736      69        0      69.0  2013.0      12109        Oregon
# ...         ...      ...       ...     ...        ...           ...
# 3933639       4        0       4.0  2013.0      55129  Pennsylvania
# 3933640       4        0       4.0  2014.0      55129  Pennsylvania
# 3933641       4        0       4.0  2015.0      55129  Pennsylvania
# 3933642       5        0       5.0  2016.0      55129  Pennsylvania
# 3933643       1        0       1.0  2017.0      55129  Pennsylvania
#
#           COUNTYNAME_FROM GEOID_TO    STATE_TO    COUNTYNAME_TO  \
# 3852732  St. Johns County    44003  Washington      Kent County
# 3852733  St. Johns County    44003  Washington      Kent County
# 3852734  St. Johns County    44003  Washington      Kent County
# 3852735  St. Johns County    44003  Washington      Kent County
# 3852736  St. Johns County    44003  Washington      Kent County
# ...                   ...      ...         ...              ...
# 3933639   Washburn County    55133  Washington  Waukesha County
# 3933640   Washburn County    55133  Washington  Waukesha County
# 3933641   Washburn County    55133  Washington  Waukesha County
# 3933642   Washburn County    55133  Washington  Waukesha County
# 3933643   Washburn County    55133  Washington  Waukesha County
#
#         STATE_FROM_RustBelt_Label STATE_TO_RustBelt_Label
# 3852732                        No                      No
# 3852733                        No                      No
# 3852734                        No                      No
# 3852735                        No                      No
# 3852736                        No                      No
# ...                           ...                     ...
# 3933639                       Yes                      No
# 3933640                       Yes                      No
# 3933641                       Yes                      No
# 3933642                       Yes                      No
# 3933643                       Yes                      No
#
# [80912 rows x 12 columns]
